# %%
import pandas as pd

# %%
patients = pd.read_csv("PATIENTS.csv")
admissions = pd.read_csv("ADMISSIONS.csv")

# %%
noteEvents = pd.read_csv("NOTEEVENTS.csv")
dict_labItems = pd.read_csv('D_LABITEMS.csv')
chartEvents = pd.read_csv('CHARTEVENTS.csv')
dict_Items = pd.read_csv('D_ITEMS.csv')
diagnosesList = pd.read_csv('DIAGNOSES_ICD.csv')
dict_diagnoses = pd.read_csv('D_ICD_DIAGNOSES.csv')
drg_diag = pd.read_csv('DRGCODES.csv')
procedureEvents = pd.read_csv('PROCEDURES_ICD.csv')
dict_procedures = pd.read_csv('D_ICD_PROCEDURES.csv')
prescriptions = pd.read_csv('PRESCRIPTIONS.csv')
inputEvents_cv = pd.read_csv('INPUTEVENTS_CV.csv')
inputEvents_mv = pd.read_csv('INPUTEVENTS_MV.csv')
outputEvents = pd.read_csv('OUTPUTEVENTS.csv')

# %%
combinedDataTable = patients.copy();

# %%
combinedDataTable = pd.merge(combinedDataTable, admissions, how = 'left', on = "SUBJECT_ID")

# %%
combinedDataTable
# Out:
#        ROW_ID_x  SUBJECT_ID GENDER                  DOB                  DOD  \
# 0           234         249      F  2075-03-13 00:00:00                  NaN
# 1           234         249      F  2075-03-13 00:00:00                  NaN
# 2           234         249      F  2075-03-13 00:00:00                  NaN
# 3           235         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 4           236         251      M  2090-03-15 00:00:00                  NaN
# ...         ...         ...    ...                  ...                  ...
# 58971     31840       44089      M  2026-05-25 00:00:00                  NaN
# 58972     31841       44115      F  2124-07-27 00:00:00                  NaN
# 58973     31842       44123      F  2049-11-26 00:00:00  2135-01-12 00:00:00
# 58974     31843       44126      F  2076-07-25 00:00:00                  NaN
# 58975     31844       44128      M  2098-07-25 00:00:00                  NaN
#
#                   DOD_HOSP DOD_SSN  EXPIRE_FLAG  ROW_ID_y  HADM_ID  ...  \
# 0                      NaN     NaN            0       321   116935  ...
# 1                      NaN     NaN            0       322   149546  ...
# 2                      NaN     NaN            0       323   158975  ...
# 3      2188-11-22 00:00:00     NaN            1       324   124271  ...
# 4                      NaN     NaN            0       325   117937  ...
# ...                    ...     ...          ...       ...      ...  ...
# 58971                  NaN     NaN            0     41057   165748  ...
# 58972                  NaN     NaN            0     41058   163623  ...
# 58973  2135-01-12 00:00:00     NaN            1     41059   116395  ...
# 58974                  NaN     NaN            0     41060   183530  ...
# 58975                  NaN     NaN            0     41061   141304  ...
#
#       INSURANCE LANGUAGE        RELIGION MARITAL_STATUS  \
# 0      Medicare      NaN        CATHOLIC       DIVORCED
# 1      Medicare     ENGL        CATHOLIC       DIVORCED
# 2      Medicare     ENGL        CATHOLIC       DIVORCED
# 3      Self Pay     HAIT   NOT SPECIFIED         SINGLE
# 4       Private      NaN           OTHER            NaN
# ...         ...      ...             ...            ...
# 58971  Medicare     ENGL  GREEK ORTHODOX        MARRIED
# 58972   Private     ENGL        CATHOLIC        MARRIED
# 58973  Medicare      NaN        CATHOLIC      SEPARATED
# 58974   Private     ENGL   NOT SPECIFIED        MARRIED
# 58975   Private     ENGL   NOT SPECIFIED        MARRIED
#
#                     ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0                       WHITE  2149-12-17 11:10:00  2149-12-17 21:35:00
# 1                       WHITE  2155-02-03 17:43:00  2155-02-03 21:26:00
# 2                       WHITE                  NaN                  NaN
# 3      BLACK/AFRICAN AMERICAN  2188-11-12 06:56:00  2188-11-12 10:10:00
# 4       UNKNOWN/NOT SPECIFIED  2110-07-27 05:00:00  2110-07-27 07:15:00
# ...                       ...                  ...                  ...
# 58971                   WHITE  2111-09-29 18:35:00  2111-09-30 07:08:00
# 58972                   WHITE                  NaN                  NaN
# 58973                   WHITE                  NaN                  NaN
# 58974                   WHITE                  NaN                  NaN
# 58975                   WHITE  2149-06-08 11:53:00  2149-06-08 15:31:00
#
#                                           DIAGNOSIS HOSPITAL_EXPIRE_FLAG  \
# 0                 UNSTABLE ANGINA;ASTHMA;BRONCHITIS                    0
# 1                              GI BLEED/ CHEST PAIN                    0
# 2                           GI BLEEDING\COLONOSCOPY                    0
# 3                                  PNEUMONIA;R/O TB                    1
# 4                           INTRACRANIAL HEAD BLEED                    0
# ...                                             ...                  ...
# 58971  CHEST PAIN;ANGINA\LEFT HEART CATHETERIZATION                    0
# 58972             CHIARI MALFORMATION BILATERAL/SDA                    0
# 58973            ABDOMINAL ANEURYSM; NO RUPTURE/SDA                    1
# 58974                                 SCOLIOSIS/SDA                    0
# 58975                                        TRAUMA                    0
#
#       HAS_CHARTEVENTS_DATA
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# ...                    ...
# 58971                    1
# 58972                    1
# 58973                    1
# 58974                    1
# 58975                    1
#
# [58976 rows x 26 columns]

# %%
labEvents = pd.read_csv('LABEVENTS.csv')
dict_labItems = pd.read_csv('D_LABITEMS.csv')

# %%
combinedLab = pd.merge(labEvents, dict_labItems, how = 'left', on = "ITEMID")
combinedLab
# Out:
#           ROW_ID_x  SUBJECT_ID   HADM_ID  ITEMID            CHARTTIME VALUE  \
# 0              281           3       NaN   50820  2101-10-12 16:07:00  7.39
# 1              282           3       NaN   50800  2101-10-12 18:17:00   ART
# 2              283           3       NaN   50802  2101-10-12 18:17:00    -1
# 3              284           3       NaN   50804  2101-10-12 18:17:00    22
# 4              285           3       NaN   50808  2101-10-12 18:17:00  0.93
# ...            ...         ...       ...     ...                  ...   ...
# 27854050  27428435       96443  103219.0   50882  2109-12-30 01:40:00    26
# 27854051  27428436       96443  103219.0   50885  2109-12-30 01:40:00   2.1
# 27854052  27428437       96443  103219.0   50902  2109-12-30 01:40:00    97
# 27854053  27428438       96443  103219.0   50911  2109-12-30 01:40:00     2
# 27854054  27428439       96443  103219.0   50912  2109-12-30 01:40:00   1.6
#
#           VALUENUM VALUEUOM      FLAG  ROW_ID_y  \
# 0             7.39    units       NaN        21
# 1              NaN      NaN       NaN         1
# 2            -1.00    mEq/L       NaN         3
# 3            22.00    mEq/L       NaN         5
# 4             0.93   mmol/L  abnormal         9
# ...            ...      ...       ...       ...
# 27854050     26.00    mEq/L       NaN        83
# 27854051      2.10    mg/dL  abnormal        86
# 27854052     97.00    mEq/L       NaN       103
# 27854053      2.00    ng/mL       NaN       112
# 27854054      1.60    mg/dL  abnormal       113
#
#                                   LABEL  FLUID   CATEGORY LOINC_CODE
# 0                                    pH  Blood  Blood Gas    11558-4
# 1                         SPECIMEN TYPE  BLOOD  BLOOD GAS        NaN
# 2                           Base Excess  Blood  Blood Gas    11555-0
# 3                  Calculated Total CO2  Blood  Blood Gas    34728-6
# 4                          Free Calcium  Blood  Blood Gas     1994-3
# ...                                 ...    ...        ...        ...
# 27854050                    Bicarbonate  Blood  Chemistry     1963-8
# 27854051               Bilirubin, Total  Blood  Chemistry     1975-2
# 27854052                       Chloride  Blood  Chemistry     2075-0
# 27854053  Creatine Kinase, MB Isoenzyme  Blood  Chemistry     6773-6
# 27854054                     Creatinine  Blood  Chemistry     2160-0
#
# [27854055 rows x 14 columns]

# %%
combinedDataTable = pd.merge(combinedDataTable, combinedLab, how = 'left', on = 'SUBJECT_ID')

# %%
combinedDataTable
# Out:
#           ROW_ID_x_x  SUBJECT_ID GENDER                  DOB  DOD DOD_HOSP  \
# 0                234         249      F  2075-03-13 00:00:00  NaN      NaN
# 1                234         249      F  2075-03-13 00:00:00  NaN      NaN
# 2                234         249      F  2075-03-13 00:00:00  NaN      NaN
# 3                234         249      F  2075-03-13 00:00:00  NaN      NaN
# 4                234         249      F  2075-03-13 00:00:00  NaN      NaN
# ...              ...         ...    ...                  ...  ...      ...
# 57516703       31844       44128      M  2098-07-25 00:00:00  NaN      NaN
# 57516704       31844       44128      M  2098-07-25 00:00:00  NaN      NaN
# 57516705       31844       44128      M  2098-07-25 00:00:00  NaN      NaN
# 57516706       31844       44128      M  2098-07-25 00:00:00  NaN      NaN
# 57516707       31844       44128      M  2098-07-25 00:00:00  NaN      NaN
#
#          DOD_SSN  EXPIRE_FLAG  ROW_ID_y_x  HADM_ID_x  ...  \
# 0            NaN            0         321     116935  ...
# 1            NaN            0         321     116935  ...
# 2            NaN            0         321     116935  ...
# 3            NaN            0         321     116935  ...
# 4            NaN            0         321     116935  ...
# ...          ...          ...         ...        ...  ...
# 57516703     NaN            0       41061     141304  ...
# 57516704     NaN            0       41061     141304  ...
# 57516705     NaN            0       41061     141304  ...
# 57516706     NaN            0       41061     141304  ...
# 57516707     NaN            0       41061     141304  ...
#
#                     CHARTTIME VALUE VALUENUM VALUEUOM      FLAG ROW_ID_y_y  \
# 0         2149-12-28 06:55:00   1.4     1.40      NaN       NaN      437.0
# 1         2149-12-28 06:55:00  29.7    29.70       pg       NaN      448.0
# 2         2149-12-28 06:55:00  33.4    33.40        %       NaN      449.0
# 3         2149-12-28 06:55:00    89    89.00       fL       NaN      450.0
# 4         2149-12-28 06:55:00   260   260.00     K/uL       NaN      465.0
# ...                       ...   ...      ...      ...       ...        ...
# 57516703  2149-06-14 05:00:00  13.6    13.60        %       NaN      477.0
# 57516704  2149-06-14 05:00:00  2.98     2.98     m/uL  abnormal      479.0
# 57516705  2149-06-14 05:00:00  11.4    11.40     K/uL  abnormal      501.0
# 57516706  2149-06-15 04:45:00  27.3    27.30        %  abnormal      421.0
# 57516707  2149-06-16 12:22:00  28.0    28.00        %  abnormal      421.0
#
#                       LABEL  FLUID    CATEGORY LOINC_CODE
# 0                   INR(PT)  Blood  Hematology     5895-7
# 1                       MCH  Blood  Hematology      785-6
# 2                      MCHC  Blood  Hematology      786-4
# 3                       MCV  Blood  Hematology      787-2
# 4            Platelet Count  Blood  Hematology      777-3
# ...                     ...    ...         ...        ...
# 57516703                RDW  Blood  Hematology      788-0
# 57516704    Red Blood Cells  Blood  Hematology      789-8
# 57516705  White Blood Cells  Blood  Hematology      804-5
# 57516706         Hematocrit  Blood  Hematology     4544-3
# 57516707         Hematocrit  Blood  Hematology     4544-3
#
# [57516708 rows x 39 columns]

# %%
combinedDataTable.to_csv("pat_labs.csv", index = False)
